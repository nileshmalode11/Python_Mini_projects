# %% [markdown]
# <a href="https://colab.research.google.com/github/nileshmalode11/Python_Mini_projects/blob/main/mini_project__ATM_system_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ATM Program without otp

print("Welcome to State Bank of Maharashtra")
p=int(input("Enter your 4 digit pin number"))
m=1000000

if(p==1232):
  print("1-withdraw")
  print("2-Balance enquiry")
  print("3-fast cash")
  c=int(input("please choose transaction:"))

  if (c==1):
    w=int(input("Enter withdraw ammount"))

    if w<m and w%100==0:
      print("please take your cash",w)
    else:
      print("Invalid cash")
  elif(c==2):
    print("available balance:",m)

  elif (c==3):
    print("1->5000")
    print("2->10000")
    print("3->15000")        
    print("4->20000")   
    x=int(inpu("Enter fast cash option"))

    if(f==1 and 5000<m):
      print("Please take your cash 5000")
    elif(f==2 and 10000<m):
      print("Please take your cash 10000")
    elif(f==3 and 15000<m):
      print("Please take your cash 15000")
    elif(f==4 and 20000<m):
      print("Please take your cash 20000")    
    else:
      print("Invalid fast cash option")
  else:
      print("Wrong choice")           
else:
  print("Wrong pin!!!")

# %%
#ATM System python program
 
import time as t
import random

#account deatil
MObile_number=8766006600
user_pin=1234
user_balance=89788.89
Acc_holder_name="Mr patil"
card_number=98909798981
c=3

#use loop for choosing option
while (c!=0):
  print("\t\t0.logout and Exit")
  print("\t\t1.View Account Balance")
  print("\t\t2.Withdraw cash")
  print("\t\t3.Chane Pin")
  print("\t\t4.Block Card")

 #choose your option
  choice=int(input("Enter number to proceed > "))
  print("\n\n")

  #for logout choose option 0
  if choice==0:
    print("Exiting. . .")
    t.sleep(2)
    print("You have been logged out.\n Thank You\n")
    break

  elif choice in(1,2,3,4):
    #use another loop for number of chances for pin

    num_of_tries = 3
    while num_of_tries != 0:
      pin=int(input("Enter Your 4-digit pin >\n "))
      
      if pin==user_pin:
        print("\nAccount holder Name:-",Acc_holder_name)

        #checking account balance 
        if choice==1:
          print("\nloading Account Balance . . .")
          t.sleep(1.2)
          print("Your Available balance is RS.",user_balance)
          break 

        #withdraw cash an display reamaining balace
        elif choice==2:
          Withdraw_Amount=int(input("Enter withdrawal amount>"))

          if Withdraw_Amount < user_balance: 
            print("Withdrawing RS.",Withdraw_Amount)
            user_balance-=Withdraw_Amount
            print("Remaining Balance.",user_balance)
            t.sleep(5)
            print("Thank You . . . Visite Again")

          else:
            print("Insufficient Balance") 
            print("\n\n Try Again with lower Balance")
            break

        # for pin change with OTP      
        elif choice==3:
          print("loading your pin change....\n\n")
          t.sleep(2)
          MO_NO=int(input("enter your 10 digite mobile number>"))
          #OTP genration
          def generateOTP():
              OTP=""

              for i in range(4):
                OTP+=str(random.randint(0,9))
              

              print("Your one time passwor",OTP)
              return OTP
          OTP=generateOTP()
          
          otp=str(input("Enter 4-digite otp>"))
          
          if otp == OTP:
            New_Pin=int(input("Enter Your New Pin in 4 digit> "))
            user_pin==New_Pin
            print("PIN changed successfully!!\n\n")
            break
          else:
            print("You Entered Wrong OTP\n\n Try Again")

            break

        #card blocking 
        elif choice==4:
          print("Loading for Card Block")
          t.sleep(2)
          z=int(input("Emter your card number"))
          if z==card_number:
            MO_NO=int(input("enter your 10 digite mobile number>"))

            OTP = generateOTP()
            
            M = str(input("Enter 4-digite otp>"))
            if M == OTP and MO_NO==Mobile_number:
              confirm=input("Are You sure? Y/N")
              if confirm in ('Y','y'):
                print("Bloack Your card SUCCESSFULLY!\n\n")

              else:
                print("Cancelling Process...")
                t.sleep(1)
                print("Process Cancelled")

            else:
              print("You entered Wrong OTP\n\n Try again")      

          break
         
      else:
        num_of_tries = num_of_tries - 1
        print("PIN Incorrect! no of tries left-", num_of_tries)
    else:      
      print("exiting...")
      print("you havebeen loged out..Thank You\n\n")
      break
  else:
   c-=1
   print("num of chance left:",c) 
   print("Invalid Input")
   print("\t\t0.Enter 0 to logout and Exit!\n\n")
# Out:
# 		0.logout and Exit
# 		1.View Account Balance
# 		2.Withdraw cash
# 		3.Chane Pin
# 		4.Block Card
# Enter number to proceed > 5
#
#
#
# num of chance left: 2
# Invalid Input
# 		0.Enter 0 to logout and Exit!
#
#
# 		0.logout and Exit
# 		1.View Account Balance
# 		2.Withdraw cash
# 		3.Chane Pin
# 		4.Block Card
# Enter number to proceed > 7
#
#
#
# num of chance left: 1
# Invalid Input
# 		0.Enter 0 to logout and Exit!
#
#
# 		0.logout and Exit
# 		1.View Account Balance
# 		2.Withdraw cash
# 		3.Chane Pin
# 		4.Block Card
# Enter number to proceed > 7
#
#
#
# num of chance left: 0
# Invalid Input
# 		0.Enter 0 to logout and Exit!
